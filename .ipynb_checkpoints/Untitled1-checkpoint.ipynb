# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://fr.wikipedia.org/wiki/%C3%89ducation'
page=requests.get(url)
soup=BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>Éducation — Wikipédia</title>
# ...

# %%
soup.find('table')
# Out:
# <table class="wikitable" style="margin: 1em;border-collapse:collapse;">
# <caption>Enseignement secondaire
# </caption>
# <tbody><tr>
# <td valign="top">
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>1</td>
# <td align="right">Corée du Sud
# </td></tr>
# <tr>
# <td>2</td>
# <td align="right">Norvège
# </td></tr>
# <tr>
# <td>3</td>
# <td align="right">Slovaquie
# </td></tr>
# <tr>
# <td>4</td>
# <td align="right">Japon
# </td></tr>
# <tr>
# <td>5</td>
# <td align="right">République tchèque
# </td></tr>
# <tr>
# <td>6</td>
# <td align="right">Suède
# </td></tr>
# <tr>
# <td>7</td>
# <td align="right">Canada
# </td></tr>
# <tr>
# <td>8</td>
# <td align="right">Finlande
# </td></tr>
# <tr>
# <td>9</td>
# <td align="right">États-Unis
# </td></tr>
# <tr>
# <td>10</td>
# <td align="right">Danemark
# </td></tr>
# <tr>
# <td>11</td>
# <td align="right">Allemagne
# </td></tr>
# <tr>
# <td>12</td>
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table class="wikitable" style="margin: 1em;border-collapse:collapse;">
# <caption>Enseignement secondaire
# </caption>
# <tbody><tr>
# <td valign="top">
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>1</td>
# <td align="right">Corée du Sud
# </td></tr>
# <tr>
# <td>2</td>
# <td align="right">Norvège
# </td></tr>
# <tr>
# <td>3</td>
# <td align="right">Slovaquie
# </td></tr>
# <tr>
# <td>4</td>
# <td align="right">Japon
# </td></tr>
# <tr>
# <td>5</td>
# <td align="right">République tchèque
# </td></tr>
# <tr>
# <td>6</td>
# <td align="right">Suède
# </td></tr>
# <tr>
# <td>7</td>
# <td align="right">Canada
# </td></tr>
# <tr>
# <td>8</td>
# <td align="right">Finlande
# </td></tr>
# <tr>
# <td>9</td>
# <td align="right">États-Unis
# </td></tr>
# <tr>
# <td>10</td>
# <td align="right">Danemark
# </td></tr>
# <tr>
# <td>11</td>
# <td align="right">Allemagne
# </td></tr>
# <tr>
# <td>12</td>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>1</td>
# <td align="right">Corée du Sud
# </td></tr>
# <tr>
# <td>2</td>
# <td align="right">Norvège
# </td></tr>
# <tr>
# <td>3</td>
# <td align="right">Slovaquie
# </td></tr>
# <tr>
# <td>4</td>
# <td align="right">Japon
# </td></tr>
# <tr>
# <td>5</td>
# <td align="right">République tchèque
# </td></tr>
# <tr>
# <td>6</td>
# <td align="right">Suède
# </td></tr>
# <tr>
# <td>7</td>
# <td align="right">Canada
# </td></tr>
# <tr>
# <td>8</td>
# <td align="right">Finlande
# </td></tr>
# <tr>
# <td>9</td>
# <td align="right">États-Unis
# </td></tr>
# <tr>
# <td>10</td>
# <td align="right">Danemark
# </td></tr>
# <tr>
# <td>11</td>
# <td align="right">Allemagne
# </td></tr>
# <tr>
# <td>12</td>
# <td align="right">Autriche
# </td></tr>
# <tr>
# <td>13</td>
# <td align="right">Nouvelle-Zélande
# </td></tr>
# <tr>
# <td>14</td>
# <td align="right">Hongrie
# ...

# %%
soup.find_all('table')[2]
# Out:
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>16</td>
# <td align="right">Irlande
# </td></tr>
# <tr>
# <td>17</td>
# <td align="right">Belgique
# </td></tr>
# <tr>
# <td>18</td>
# <td align="right">Suisse
# </td></tr>
# <tr>
# <td>19</td>
# <td align="right">Pays-Bas
# </td></tr>
# <tr>
# <td>20</td>
# <td align="right">Australie
# </td></tr>
# <tr>
# <td>21</td>
# <td align="right">Grèce
# </td></tr>
# <tr>
# <td>22</td>
# <td align="right">Royaume-Uni
# </td></tr>
# <tr>
# <td>23</td>
# <td align="right">Luxembourg
# </td></tr>
# <tr>
# <td>24</td>
# <td align="right">Islande
# </td></tr>
# <tr>
# <td>25</td>
# <td align="right">Italie
# </td></tr>
# <tr>
# <td>26</td>
# <td align="right">Espagne
# </td></tr>
# <tr>
# <td>27</td>
# <td align="right">Pologne
# </td></tr>
# <tr>
# <td>28</td>
# <td align="right">Portugal
# </td></tr>
# <tr>
# <td>29</td>
# <td align="right">Turquie
# </td></tr>
# ...

# %%
soup.find_all('table')[2]
# Out:
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>16</td>
# <td align="right">Irlande
# </td></tr>
# <tr>
# <td>17</td>
# <td align="right">Belgique
# </td></tr>
# <tr>
# <td>18</td>
# <td align="right">Suisse
# </td></tr>
# <tr>
# <td>19</td>
# <td align="right">Pays-Bas
# </td></tr>
# <tr>
# <td>20</td>
# <td align="right">Australie
# </td></tr>
# <tr>
# <td>21</td>
# <td align="right">Grèce
# </td></tr>
# <tr>
# <td>22</td>
# <td align="right">Royaume-Uni
# </td></tr>
# <tr>
# <td>23</td>
# <td align="right">Luxembourg
# </td></tr>
# <tr>
# <td>24</td>
# <td align="right">Islande
# </td></tr>
# <tr>
# <td>25</td>
# <td align="right">Italie
# </td></tr>
# <tr>
# <td>26</td>
# <td align="right">Espagne
# </td></tr>
# <tr>
# <td>27</td>
# <td align="right">Pologne
# </td></tr>
# <tr>
# <td>28</td>
# <td align="right">Portugal
# </td></tr>
# <tr>
# <td>29</td>
# <td align="right">Turquie
# </td></tr>
# ...

# %%
soup.find_all('table')[4]
# Out:
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>1</td>
# <td align="right">Allemagne
# </td></tr>
# <tr>
# <td>2</td>
# <td align="right">Grèce
# </td></tr>
# <tr>
# <td>3</td>
# <td align="right">Norvège
# </td></tr>
# <tr>
# <td>4</td>
# <td align="right">Japon
# </td></tr>
# <tr>
# <td>5</td>
# <td align="right">Irlande
# </td></tr>
# <tr>
# <td>6</td>
# <td align="right">Suisse
# </td></tr>
# <tr>
# <td>7</td>
# <td align="right">République tchèque
# </td></tr>
# <tr>
# <td>8</td>
# <td align="right">Hongrie
# </td></tr>
# <tr>
# <td>9</td>
# <td align="right">Danemark
# </td></tr>
# <tr>
# <td>10</td>
# <td align="right">Pologne
# </td></tr>
# <tr>
# <td>11</td>
# <td align="right">Finlande
# </td></tr></tbody></table>

# %%
soup.find('table',class_='wikitable')
# Out:
# <table class="wikitable" style="margin: 1em;border-collapse:collapse;">
# <caption>Enseignement secondaire
# </caption>
# <tbody><tr>
# <td valign="top">
# <table>
# <tbody><tr>
# <th style="background:#efefef;">Rang
# </th>
# <th style="background:#efefef;">Pays
# </th></tr>
# <tr>
# <td>1</td>
# <td align="right">Corée du Sud
# </td></tr>
# <tr>
# <td>2</td>
# <td align="right">Norvège
# </td></tr>
# <tr>
# <td>3</td>
# <td align="right">Slovaquie
# </td></tr>
# <tr>
# <td>4</td>
# <td align="right">Japon
# </td></tr>
# <tr>
# <td>5</td>
# <td align="right">République tchèque
# </td></tr>
# <tr>
# <td>6</td>
# <td align="right">Suède
# </td></tr>
# <tr>
# <td>7</td>
# <td align="right">Canada
# </td></tr>
# <tr>
# <td>8</td>
# <td align="right">Finlande
# </td></tr>
# <tr>
# <td>9</td>
# <td align="right">États-Unis
# </td></tr>
# <tr>
# <td>10</td>
# <td align="right">Danemark
# </td></tr>
# <tr>
# <td>11</td>
# <td align="right">Allemagne
# </td></tr>
# <tr>
# <td>12</td>
# ...

# %%
soup.find_all('th')
# Out:
# [<th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
# ...

# %%
world_titles=soup.find_all('th')

# %%
world_titles
# Out:
# [<th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
#  <th style="background:#efefef;">Rang
#  </th>,
#  <th style="background:#efefef;">Pays
#  </th>,
# ...

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# Use a set to remove duplicate entries and preserve the order
unique_world_table_titles = list(dict.fromkeys(world_table_titles))

print(unique_world_table_titles)
# Out:
# ['Rang', 'Pays', 'v\xa0· mCulture', 'Types', 'Transmission', 'Théories', 'Disciplines et sous-disciplines']

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=unique_world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rang, Pays, v · mCulture, Types, Transmission, Théories, Disciplines et sous-disciplines]
# Index: []

# %%
columns_data=table.find_all('tr')
columns_data
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD billions)
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
#  </td>
#  <td>Food industry
#  </td>
#  <td style="text-align:center;">165
#  </td>
#  <td style="text-align:center;">155,000
#  </td>
#  <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
#  </td></tr>,
#  <tr>
#  <td>2
#  </td>
#  <td><a href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
#  </td>
#  <td>Conglomerate
#  </td>
#  <td style="text-align:center;">125
#  </td>
#  <td style="text-align:center;">120,000
#  </td>
#  <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
#  </td></tr>,
#  <tr>
#  <td>3
#  </td>
# ...

# %%
for row in columns_data[1:]:
  row_data=  row.find_all('td')
  individual_row_data=[data.text.strip() for data in row_data]
    
    
  print(individual_row_data)
# Out:
# ['1', 'Cargill', 'Food industry', '165', '155,000', 'Minnetonka, Minnesota']
# ['2', 'Koch Industries', 'Conglomerate', '125', '120,000', 'Wichita, Kansas']
# ['3', 'Publix Super Markets', 'Retail', '48', '230,000', 'Winter Haven, Florida']
# ['4', 'Mars, Incorporated', 'Food industry', '45', '140,000', 'McLean, Virginia']
# ['5', 'Pilot Corporation', 'Petroleum industry and Retail', '41.9', '30,000', 'Knoxville, Tennessee']
# ['6', 'H-E-B', 'Retail', '38.9', '145,000', 'San Antonio, Texas']
# ['7', 'Reyes Holdings', 'Wholesaling', '35.3', '33,000', 'Rosemont, Illinois']
# ['8', 'C&S Wholesale Grocers', 'Wholesaling', '33', '14,000', 'Keene, New Hampshire']
# ['9', 'Enterprise Holdings', 'Car rental', '30', '80,000', 'Clayton, Missouri']
# ['10', "Love's", 'Petroleum industry and Retail', '25.5', '38,000', 'Oklahoma City, Oklahoma']

# %%
columns_data=table.find_all('tr')

# %%
for row in columns_data[1:]   :
    row_data=row.find_all('td')
    individuals_row_data=[data.text.strip() for data in row_data]
    print(row_data)
# Out:
# [<td>1
# </td>, <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
# </td>, <td>Food industry
# </td>, <td style="text-align:center;">165
# </td>, <td style="text-align:center;">155,000
# </td>, <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
# </td>]
# [<td>2
# </td>, <td><a href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
# </td>, <td>Conglomerate
# </td>, <td style="text-align:center;">125
# </td>, <td style="text-align:center;">120,000
# </td>, <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
# </td>]
# [<td>3
# </td>, <td><a class="mw-redirect" href="/wiki/Publix_Super_Markets" title="Publix Super Markets">Publix Super Markets</a>
# </td>, <td>Retail
# </td>, <td style="text-align:center;">48
# </td>, <td style="text-align:center;">230,000
# </td>, <td><a href="/wiki/Winter_Haven,_Florida" title="Winter Haven, Florida">Winter Haven, Florida</a>
# </td>]
# [<td>4
# ...

# %% [markdown]
# # Education

# %%
for row in columns_data[1:]:
    row_data=row.find_all('td')
    individuals_row_data=[data.text.strip() for data in row_data]
    length=len(df)
    print(length)
    df.loc[length]=individuals_row_data
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[221], line 6
#       4 length=len(df)
#       5 print(length)
# ----> 6 df.loc[length]=individuals_row_data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
#    1829     # must come after setting of missing
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rang, Pays, v · mCulture, Types, Transmission, Théories, Disciplines et sous-disciplines]
# Index: []

# %%
df.to_csv(r'C:\Users\dorra\Downloads\archive\education.csv',index=False)
